# %%
#Problem 1

# %%
P = var('P')

# %%
def f(P): return P*(10 - P)

# %%
def H(P): return f(P) - P

# %%
derf = derivative(f(P), P)

# %%
derf
# Out:
# -2*P + 10

# %%
der2f = derivative(f(P), P, 2)

# %%
der2f
# Out:
# -2

# %%
derH = derivative(H(P), P)

# %%
derH
# Out:
# -2*P + 9

# %%
der2H = derivative(H(P), P, 2)

# %%
der2H
# Out:
# -2

# %%
p = []

# %%
p.append(plot(f(P),(P,0,10), ymin=0, color='blue', legend_label='f(P)'))

# %%
p.append(plot(P,(P,0,10), ymin=0, color='green', legend_label='y = P'))

# %%
p.append(plot(H(P),(P,0,10), ymin=0, color='red', legend_label='H(P)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
derH.roots()
# Out:
# [(9/2, 1)]

# %%
H(9/2)
# Out:
# 81/4

# %%
numerical_approx(81/4)
# Out:
# 20.2500000000000

# %%
#Problem 2

# %%
def f(P): return -0.025*P^2 + 4*P

# %%
def H(P): return f(P) - P

# %%
derH = derivative(H(P), P)

# %%
derH
# Out:
# -0.0500000000000000*P + 3

# %%
derH2 = derivative(H(P), P, 2)

# %%
derH2
# Out:
# -0.0500000000000000

# %%
p = []

# %%
p.append(plot(f(P),(P,0,200), ymin=0, color='blue', legend_label='f(P)'))

# %%
p.append(plot(P,(P,0,200), ymin=0, color='green', legend_label='y = P'))

# %%
p.append(plot(H(P),(P,0,200), ymin=0, color='red', legend_label='H(P)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
derH.roots()
# Out:
# [(60, 1)]

# %%
H(60)
# Out:
# 90.0000000000000

# %%
#Problem_3

# %%
def f(P): return -0.01*P^2 + 2*P

# %%
def H(P): return f(P) - P

# %%
derH = derivative(H(P), P)

# %%
derH
# Out:
# -0.0200000000000000*P + 1

# %%
derH2 = derivative(H(P), P, 2)

# %%
derH2
# Out:
# -0.0200000000000000

# %%
derH.roots()
# Out:
# [(50, 1)]

# %%
H(50)
# Out:
# 25.0000000000000

# %%
p = []

# %%
p.append(plot(f(P),(P,0,200), ymin=0, color='blue', legend_label='f(P)'))

# %%
p.append(plot(P,(P,0,200), ymin=0, color='green', legend_label='y = P'))

# %%
p.append(plot(H(P),(P,0,200), ymin=0, color='red', legend_label='H(P)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem_4

# %%
def f(P): return 40*sqrt(P)

# %%
def H(P): return f(P) - P

# %%
derH = derivative(H(P), P)

# %%
derH
# Out:
# 20/sqrt(P) - 1

# %%
derH2 = derivative(H(P), P, 2)

# %%
derH2
# Out:
# -10/P^(3/2)

# %%
derH.roots()
# Out:
# [(400, 1)]

# %%
H(400)
# Out:
# 400

# %%
p = []

# %%
p.append(plot(f(P),(P,0,1600), ymin=0, color='blue', legend_label='f(P)'))

# %%
p.append(plot(P,(P,0,1600), ymin=0, color='green', legend_label='y = P'))

# %%
p.append(plot(H(P),(P,0,1600), ymin=0, color='red', legend_label='H(P)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem_5

# %%
def f(P): return 0.237*P*sqrt(2000 - P^2)

# %%
def H(P): return f(P) - P

# %%
derH = derivative(H(P), P)

# %%
derH
# Out:
# -0.237000000000000*P^2/sqrt(-P^2 + 2000) + 0.237000000000000*sqrt(-P^2 + 2000) - 1

# %%
derH2 = derivative(H(P), P, 2)

# %%
derH2
# Out:
# -0.237000000000000*P^3/(-P^2 + 2000)^(3/2) - 0.711000000000000*P/sqrt(-P^2 + 2000)

# %%
derH.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-a906b41d7305> in <module>
# ----> 1 derH.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
p = []

# %%
p.append(plot(f(P),(P,0,44.7), ymin=0, color='blue', legend_label='f(P)'))

# %%
p.append(plot(P,(P,0,44.7), ymin=0, color='green', legend_label='y = P'))

# %%
p.append(plot(H(P),(P,0,44.7), ymin=0, color='red', legend_label='H(P)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
derH.find_root(20, 40)
# Out:
# 30.512665365915776

# %%
H(30.512665365915776)
# Out:
# 205.922855837928

# %%
#Problem_6

# %%
def f(P): return -1.108e-3*P^3 + 7.154e-2*P^2 - 3.381e-2*P + 4.000

# %%
def H(P): return f(P) - P

# %%
derH = derivative(H(P), P)

# %%
derH
# Out:
# -0.00332400000000000*P^2 + 0.143080000000000*P - 1.03381000000000

# %%
derH2 = derivative(H(P), P, 2)

# %%
derH2
# Out:
# -0.00664800000000000*P + 0.143080000000000

# %%
derH.roots()
# Out:
# [(-1/1662*sqrt(420396790) + 17885/831, 1),
#  (1/1662*sqrt(420396790) + 17885/831, 1)]

# %%
p = []

# %%
p.append(plot(f(P),(P,0,100), ymin=0, color='blue', legend_label='f(P)'))

# %%
p.append(plot(P,(P,0,100), ymin=0, color='green', legend_label='y = P'))

# %%
p.append(plot(H(P),(P,0,100), ymin=0, color='red', legend_label='H(P)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
derH.find_root(0, 20)
# Out:
# 9.185571641805463

# %%
derH.find_root(20, 40)
# Out:
# 33.858953027267944

# %%
def second_derH2(P): return -0.00664800000000000*P + 0.143080000000000

# %%
second_derH2(9.185571641805463)
# Out:
# 0.0820143197252773

# %%
second_derH2(33.858953027267944)
# Out:
# -0.0820143197252773

# %%
H(0)
# Out:
# 4.00000000000000

# %%
H(9.185571641805463)
# Out:
# -0.318701237440795

# %%
H(33.858953027267944)
# Out:
# 8.00268691570335

# %%
H(50)
# Out:
# -7.34049999999998
